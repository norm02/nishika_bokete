# %% [markdown]
# # ボケ判定AIを作ろう！-チュートリアル1
# このnotebookは、Nishikaコンペティション [ボケ判定AIを作ろう！](https://www.nishika.com/competitions/) のチュートリアルです。
#
# 「ボケて」データを用いて、画像データと文章からそのボケてが面白いか面白くないかを予測することをテーマとしています。
#
# このNotebookでは、画像とテキストそれぞれの特徴量生成を以下のような方法で行っていきます。
#
# - CNNモデルを用いた画像データの特徴量化
# - BERTモデルを用いたテキストデータの特徴量化
#
# 特徴量の作成では、テキストと画像それぞれ別々で作成していますので、画像データとテキストデータを組み合わせた特徴量を入れることで精度向上が見込めるかも知れませんので、いろいろと試していただければと思います。

# %% [markdown]
# | 要素 | 説明 |
# | ---- | ---- |
# |id | ID|
# |odai_photo_file_name | ボケてのお題画像|
# |text | ボケての文章|
# |is_laugh | 面白さ（面白い：１、面白くない：０）|

# %% [markdown]
# ディレクトリ構成は以下のように設定します
#
# ```
# ├── train.zip
# │ ├── xxx.jpg
# │ └── yyy.jpg
# ├── test.zip
# │ ├── xxx.jpg
# │ └── yyy.jpg
# ├── train.csv
# ├── test.csv
# ├── sample_submission.csv
# └── submission.csv(今回のbaselineで生成されるsubmissionファイル)
#
#
# ```
#
# ### setting
# ページ上部の「ランタイム」>「ランタイムのタイプを変更」から「GPU」「ハイメモリ」を選択

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !nvidia-smi
# Out:
# Mon Sep  5 07:51:44 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Library

# %%
# !pip install sudachitra
! wget https://sudachi.s3.ap-northeast-1.amazonaws.com/chitra/chiTra-1.0.tar.gz
! tar -zxvf chiTra-1.0.tar.gz
# Out:
# --2022-09-05 08:01:43--  https://sudachi.s3.ap-northeast-1.amazonaws.com/chitra/chiTra-1.0.tar.gz
# Resolving sudachi.s3.ap-northeast-1.amazonaws.com (sudachi.s3.ap-northeast-1.amazonaws.com)... 52.219.1.7
# Connecting to sudachi.s3.ap-northeast-1.amazonaws.com (sudachi.s3.ap-northeast-1.amazonaws.com)|52.219.1.7|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 415004253 (396M) [application/x-gzip]
# Saving to: ‘chiTra-1.0.tar.gz’
#
# chiTra-1.0.tar.gz   100%[===================>] 395.78M  30.9MB/s    in 14s
#
# 2022-09-05 08:01:58 (28.1 MB/s) - ‘chiTra-1.0.tar.gz’ saved [415004253/415004253]
#
# chiTra-1.0/
# chiTra-1.0/config.json
# chiTra-1.0/LICENSE
# chiTra-1.0/pytorch_model.bin
# chiTra-1.0/README.md
# chiTra-1.0/tokenizer_config.json
# chiTra-1.0/vocab.txt

# %%
# !pip install -U ginza ja_ginza_electra
# !git lfs install
# !pip install -U "spacy[cuda110]"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ginza in /usr/local/lib/python3.7/dist-packages (5.1.2)
# Requirement already satisfied: ja_ginza_electra in /usr/local/lib/python3.7/dist-packages (5.1.0)
# Collecting ja_ginza_electra
#   Using cached ja_ginza_electra-5.1.2-py3-none-any.whl (2.8 MB)
# Requirement already satisfied: SudachiPy<0.7.0,>=0.6.2 in /usr/local/lib/python3.7/dist-packages (from ginza) (0.6.6)
# Requirement already satisfied: plac>=1.3.3 in /usr/local/lib/python3.7/dist-packages (from ginza) (1.3.5)
# Requirement already satisfied: spacy<3.5.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from ginza) (3.2.4)
# Requirement already satisfied: SudachiDict-core>=20210802 in /usr/local/lib/python3.7/dist-packages (from ginza) (20220729)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (4.64.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (8.0.17)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (21.3)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (3.10.0.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (3.3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (2.11.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (2.0.8)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (1.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (2.23.0)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (0.6.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (2.0.6)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (0.4.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (57.4.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (1.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (3.0.7)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (1.21.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (0.7.8)
# Requirement already satisfied: click<8.1.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (7.1.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (3.0.10)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.2.0->ginza) (1.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.5.0,>=3.2.0->ginza) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.5.0,>=3.2.0->ginza) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.2.0->ginza) (5.2.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.2.0->ginza) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.2.0->ginza) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.2.0->ginza) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.2.0->ginza) (3.0.4)
# Requirement already satisfied: sudachitra<0.2.0,>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from ja_ginza_electra) (0.1.7)
# Requirement already satisfied: spacy-transformers<1.2.0,>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from ja_ginza_electra) (1.1.7)
# Requirement already satisfied: ginza-transformers<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from ja_ginza_electra) (0.4.2)
# Requirement already satisfied: transformers<4.21.0,>=3.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy-transformers<1.2.0,>=1.1.2->ja_ginza_electra) (4.18.0)
# Requirement already satisfied: spacy-alignments<1.0.0,>=0.7.2 in /usr/local/lib/python3.7/dist-packages (from spacy-transformers<1.2.0,>=1.1.2->ja_ginza_electra) (0.8.5)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from spacy-transformers<1.2.0,>=1.1.2->ja_ginza_electra) (1.12.1+cu113)
# Requirement already satisfied: logzero~=1.7.0 in /usr/local/lib/python3.7/dist-packages (from sudachitra<0.2.0,>=0.1.6->ja_ginza_electra) (1.7.0)
# Requirement already satisfied: tokenizers>=0.10.3 in /usr/local/lib/python3.7/dist-packages (from sudachitra<0.2.0,>=0.1.6->ja_ginza_electra) (0.12.1)
# Requirement already satisfied: progressbar2~=3.53.1 in /usr/local/lib/python3.7/dist-packages (from sudachitra<0.2.0,>=0.1.6->ja_ginza_electra) (3.53.3)
# Requirement already satisfied: python-utils>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from progressbar2~=3.53.1->sudachitra<0.2.0,>=0.1.6->ja_ginza_electra) (3.3.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from progressbar2~=3.53.1->sudachitra<0.2.0,>=0.1.6->ja_ginza_electra) (1.15.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers<4.21.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->ja_ginza_electra) (6.0)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers<4.21.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->ja_ginza_electra) (0.0.53)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<4.21.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->ja_ginza_electra) (2022.6.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<4.21.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->ja_ginza_electra) (4.12.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers<4.21.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->ja_ginza_electra) (0.9.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<4.21.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->ja_ginza_electra) (3.8.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.5.0,>=3.2.0->ginza) (2.0.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<4.21.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->ja_ginza_electra) (1.1.0)
# Installing collected packages: ja-ginza-electra
#   Attempting uninstall: ja-ginza-electra
#     Found existing installation: ja-ginza-electra 5.1.0
#     Uninstalling ja-ginza-electra-5.1.0:
#       Successfully uninstalled ja-ginza-electra-5.1.0
# Successfully installed ja-ginza-electra-5.1.2
# Error: Failed to call git rev-parse --git-dir --show-toplevel: "fatal: not a git repository (or any of the parent directories): .git\n"
# Git LFS initialized.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spacy[cuda110] in /usr/local/lib/python3.7/dist-packages (3.2.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy[cuda110]) (1.8.2)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy[cuda110]) (1.21.6)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy[cuda110]) (3.3.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy[cuda110]) (2.0.8)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy[cuda110]) (1.0.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy[cuda110]) (57.4.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy[cuda110]) (2.4.4)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy[cuda110]) (0.6.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy[cuda110]) (2.11.3)
# Requirement already satisfied: click<8.1.0 in /usr/local/lib/python3.7/dist-packages (from spacy[cuda110]) (7.1.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy[cuda110]) (0.10.1)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy[cuda110]) (3.10.0.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy[cuda110]) (4.64.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /usr/local/lib/python3.7/dist-packages (from spacy[cuda110]) (8.0.17)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy[cuda110]) (1.0.8)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /usr/local/lib/python3.7/dist-packages (from spacy[cuda110]) (3.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy[cuda110]) (3.0.7)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy[cuda110]) (0.4.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy[cuda110]) (2.0.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy[cuda110]) (21.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy[cuda110]) (2.23.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy[cuda110]) (0.7.8)
# Requirement already satisfied: cupy-cuda110<11.0.0,>=5.0.0b4 in /usr/local/lib/python3.7/dist-packages (from spacy[cuda110]) (10.6.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy[cuda110]) (3.8.1)
# Requirement already satisfied: fastrlock>=0.5 in /usr/local/lib/python3.7/dist-packages (from cupy-cuda110<11.0.0,>=5.0.0b4->spacy[cuda110]) (0.8)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy[cuda110]) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy[cuda110]) (5.2.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy[cuda110]) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy[cuda110]) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy[cuda110]) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy[cuda110]) (2022.6.15)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy[cuda110]) (2.0.1)

# %%
# !pip install -U ginza https://github.com/megagonlabs/ginza/releases/download/latest/ja_ginza_electra-latest-with-model.tar.gz
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting https://github.com/megagonlabs/ginza/releases/download/latest/ja_ginza_electra-latest-with-model.tar.gz
#   Downloading https://github.com/megagonlabs/ginza/releases/download/latest/ja_ginza_electra-latest-with-model.tar.gz (809.7 MB)
#      |████████████████████████████████| 809.7 MB 4.7 kB/s
# Requirement already satisfied: ginza in /usr/local/lib/python3.7/dist-packages (5.1.2)
# Requirement already satisfied: spacy<3.3.0,>=3.2.1 in /usr/local/lib/python3.7/dist-packages (from ja-ginza-electra==5.1.0) (3.2.4)
# Requirement already satisfied: sudachipy<0.7.0,>=0.6.2 in /usr/local/lib/python3.7/dist-packages (from ja-ginza-electra==5.1.0) (0.6.6)
# Requirement already satisfied: sudachidict_core>=20210802 in /usr/local/lib/python3.7/dist-packages (from ja-ginza-electra==5.1.0) (20220729)
# Requirement already satisfied: sudachitra<0.2.0,>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from ja-ginza-electra==5.1.0) (0.1.7)
# Requirement already satisfied: ginza-transformers<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from ja-ginza-electra==5.1.0) (0.4.2)
# Requirement already satisfied: spacy-transformers<1.2.0,>=1.1.3 in /usr/local/lib/python3.7/dist-packages (from ja-ginza-electra==5.1.0) (1.1.7)
# Requirement already satisfied: plac>=1.3.3 in /usr/local/lib/python3.7/dist-packages (from ginza) (1.3.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.1->ja-ginza-electra==5.1.0) (4.64.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.1->ja-ginza-electra==5.1.0) (0.7.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.1->ja-ginza-electra==5.1.0) (3.0.7)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.1->ja-ginza-electra==5.1.0) (8.0.17)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.1->ja-ginza-electra==5.1.0) (2.23.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.1->ja-ginza-electra==5.1.0) (1.8.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.1->ja-ginza-electra==5.1.0) (1.0.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.1->ja-ginza-electra==5.1.0) (2.11.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.1->ja-ginza-electra==5.1.0) (21.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.1->ja-ginza-electra==5.1.0) (0.10.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.1->ja-ginza-electra==5.1.0) (3.3.0)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.1->ja-ginza-electra==5.1.0) (0.4.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.1->ja-ginza-electra==5.1.0) (57.4.0)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.1->ja-ginza-electra==5.1.0) (3.10.0.2)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.1->ja-ginza-electra==5.1.0) (1.21.6)
# Requirement already satisfied: click<8.1.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.1->ja-ginza-electra==5.1.0) (7.1.2)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.1->ja-ginza-electra==5.1.0) (0.6.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.1->ja-ginza-electra==5.1.0) (2.4.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.1->ja-ginza-electra==5.1.0) (2.0.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.1->ja-ginza-electra==5.1.0) (1.0.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.1->ja-ginza-electra==5.1.0) (2.0.8)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.1->ja-ginza-electra==5.1.0) (3.0.10)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.3.0,>=3.2.1->ja-ginza-electra==5.1.0) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.1->ja-ginza-electra==5.1.0) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.1->ja-ginza-electra==5.1.0) (5.2.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.1->ja-ginza-electra==5.1.0) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.1->ja-ginza-electra==5.1.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.1->ja-ginza-electra==5.1.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.1->ja-ginza-electra==5.1.0) (2022.6.15)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from spacy-transformers<1.2.0,>=1.1.3->ja-ginza-electra==5.1.0) (1.12.1+cu113)
# Requirement already satisfied: transformers<4.21.0,>=3.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy-transformers<1.2.0,>=1.1.3->ja-ginza-electra==5.1.0) (4.18.0)
# Requirement already satisfied: spacy-alignments<1.0.0,>=0.7.2 in /usr/local/lib/python3.7/dist-packages (from spacy-transformers<1.2.0,>=1.1.3->ja-ginza-electra==5.1.0) (0.8.5)
# Requirement already satisfied: tokenizers>=0.10.3 in /usr/local/lib/python3.7/dist-packages (from sudachitra<0.2.0,>=0.1.6->ja-ginza-electra==5.1.0) (0.12.1)
# Requirement already satisfied: progressbar2~=3.53.1 in /usr/local/lib/python3.7/dist-packages (from sudachitra<0.2.0,>=0.1.6->ja-ginza-electra==5.1.0) (3.53.3)
# Requirement already satisfied: logzero~=1.7.0 in /usr/local/lib/python3.7/dist-packages (from sudachitra<0.2.0,>=0.1.6->ja-ginza-electra==5.1.0) (1.7.0)
# Requirement already satisfied: python-utils>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from progressbar2~=3.53.1->sudachitra<0.2.0,>=0.1.6->ja-ginza-electra==5.1.0) (3.3.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from progressbar2~=3.53.1->sudachitra<0.2.0,>=0.1.6->ja-ginza-electra==5.1.0) (1.15.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<4.21.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.3->ja-ginza-electra==5.1.0) (4.12.0)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers<4.21.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.3->ja-ginza-electra==5.1.0) (0.0.53)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<4.21.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.3->ja-ginza-electra==5.1.0) (3.8.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers<4.21.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.3->ja-ginza-electra==5.1.0) (0.9.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<4.21.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.3->ja-ginza-electra==5.1.0) (2022.6.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers<4.21.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.3->ja-ginza-electra==5.1.0) (6.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.3.0,>=3.2.1->ja-ginza-electra==5.1.0) (2.0.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<4.21.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.3->ja-ginza-electra==5.1.0) (1.1.0)
# Building wheels for collected packages: ja-ginza-electra
#   Building wheel for ja-ginza-electra (setup.py) ... done
#   Created wheel for ja-ginza-electra: filename=ja_ginza_electra-5.1.0-py3-none-any.whl size=809689557 sha256=f3eb1d79cf3c68c58589ca19439b08e1e8065a27d384da59f5f47c13ca7f7bfb
#   Stored in directory: /root/.cache/pip/wheels/24/85/bc/ba8bfdd438033abba357c5f94676b4d3aef4df9951b8a5024c
# Successfully built ja-ginza-electra
# Installing collected packages: ja-ginza-electra
#   Attempting uninstall: ja-ginza-electra
#     Found existing installation: ja-ginza-electra 5.1.2
#     Uninstalling ja-ginza-electra-5.1.2:
#       Successfully uninstalled ja-ginza-electra-5.1.2
# Successfully installed ja-ginza-electra-5.1.0

# %%
#!pip install keras-efficientnet-v2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keras-efficientnet-v2 in /usr/local/lib/python3.7/dist-packages (1.2.2)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.7/dist-packages (from keras-efficientnet-v2) (2.8.2+zzzcolab20220719082949)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-efficientnet-v2) (2.8.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-efficientnet-v2) (14.0.6)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-efficientnet-v2) (1.14.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-efficientnet-v2) (3.17.3)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-efficientnet-v2) (3.1.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-efficientnet-v2) (1.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-efficientnet-v2) (3.3.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-efficientnet-v2) (2.0.7)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-efficientnet-v2) (0.5.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-efficientnet-v2) (3.10.0.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-efficientnet-v2) (1.47.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-efficientnet-v2) (1.15.0)
# Requirement already satisfied: tensorflow-estimator<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-efficientnet-v2) (2.8.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-efficientnet-v2) (1.1.2)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-efficientnet-v2) (2.8.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-efficientnet-v2) (1.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-efficientnet-v2) (1.6.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-efficientnet-v2) (0.26.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-efficientnet-v2) (57.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-efficientnet-v2) (0.2.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow->keras-efficientnet-v2) (1.21.6)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow->keras-efficientnet-v2) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow->keras-efficientnet-v2) (1.5.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->keras-efficientnet-v2) (1.35.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->keras-efficientnet-v2) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->keras-efficientnet-v2) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->keras-efficientnet-v2) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->keras-efficientnet-v2) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->keras-efficientnet-v2) (2.23.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->keras-efficientnet-v2) (3.4.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->keras-efficientnet-v2) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->keras-efficientnet-v2) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->keras-efficientnet-v2) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow->keras-efficientnet-v2) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow->keras-efficientnet-v2) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow->keras-efficientnet-v2) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->keras-efficientnet-v2) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->keras-efficientnet-v2) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->keras-efficientnet-v2) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->keras-efficientnet-v2) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->keras-efficientnet-v2) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow->keras-efficientnet-v2) (3.2.0)

# %%
# !pip install --quiet transformers==4.18.0
# !pip install --quiet tokenizers==0.12.1
# !pip install --quiet sentencepiece
# !pip install --quiet japanize-matplotlib
# !pip install transformers fugashi ipadic >> /dev/null

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import japanize_matplotlib

import torch
import transformers

from sklearn.metrics import mean_squared_error
from sklearn.metrics import log_loss
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

import sys
import os
import re
import random

from time import time
from tqdm import tqdm

from contextlib import contextmanager
import lightgbm as lgb

import re
import requests
import unicodedata
import nltk
from nltk.corpus import wordnet
from bs4 import BeautifulSoup
nltk.download(['wordnet', 'stopwords', 'punkt'])
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# # Setting

# %%
pd.set_option('max_rows', 400)
pd.set_option('max_columns', 1000)

# %%
def seed_everything(seed=1234):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)

seed_everything(42)

# %%
INPUT = "/content/drive/MyDrive/nishika/" # 所望のディレクトリに変更してください。
train_image_path = "/content/drive/MyDrive/nishika/train/"
test_image_path = "/content/drive/MyDrive/nishika/test/"

# %% [markdown]
# # Read Data
# 学習データと推論データについて、目的変数の分布などを確認していきます。

# %%
train_df = pd.read_csv(os.path.join(INPUT, "train.csv"))
test_df = pd.read_csv(os.path.join(INPUT, "test.csv"))
submission_df = pd.read_csv(os.path.join(INPUT, "sample_submission.csv"))

# %%
print(f"train_data: {train_df.shape}")
display(train_df.head())

print(f"test_data: {test_df.shape}")
display(test_df.head())
# Out:
# train_data: (24962, 4)
#           id odai_photo_file_name  \
# 0  ge5kssftl       9fkys1gb2r.jpg
# 1  r7sm6tvkj       c6ag0m1lak.jpg
# 2  yp5aze0bh       whtn6gb9ww.jpg
# 3  ujaixzo56       6yk5cwmrsy.jpg
# 4  7vkeveptl       0i9gsa2jsm.jpg
#
#                                             text  is_laugh
# 0             君しょっちゅうソレ自慢するけど、ツムジ２個ってそんなに嬉しいのかい？         0
# 1                            これでバレない？授業中寝てもバレない？         0
# 2  「あなたも感じる？」\n『ああ…、感じてる…』\n「後ろに幽霊いるよね…」\n『女のな…』         0
# 3                 大塚愛聞いてたらお腹減った…さく、らんぼと牛タン食べたい…          0
# 4                                    熊だと思ったら嫁だった         0
# test_data: (6000, 3)
#           id odai_photo_file_name  \
# 0  rfdjcfsqq       nc1kez326b.jpg
# 1  tsgqmfpef       49xt2fmjw0.jpg
# 2  owjcthkz2       9dtscjmyfh.jpg
# 3  rvgaocjyy       osa3n56tiv.jpg
# 4  uxtwu5i69       yb1yqs4pvb.jpg
#
#                                                 text
# 0                          僕のママ、キャラ弁のゆでたまごに８時間かかったんだ
# 1                                          かわいいが作れた！
# 2                                           来世の志茂田景樹
# 3                       ちょ、あの、オカン、これ水風呂やねんけど、なんの冗談??
# 4  「今日は皆さんにザリガニと消防車の違いを知ってもらいたいと思います」『どっちも同じだろ。両方...

# %%
# 目的変数の分布を確認する
sns.countplot(x="is_laugh", data=train_df)

# %%
train_df["is_laugh"].value_counts()
# Out:
# 0    12481
# 1    12481
# Name: is_laugh, dtype: int64

# %%
# 画像の重複があるか確認する
print(train_df["odai_photo_file_name"].duplicated().sum())
print(test_df["odai_photo_file_name"].duplicated().sum())
# Out:
# 0
# 0

# %%
# 文書の長さとflagの関係を確認する
train_df["text_len"] = train_df["text"].str.len()
test_df["text_len"] = test_df["text"].str.len()

sns.boxplot(x="is_laugh", y="text_len", data=train_df)

# %% [markdown]
# 目的変数の分布と、文章の長さについて確認しました。続いて、実際に画像と文章を合わせてみてみましょう。

# %% [markdown]
# 個人的な主観も含まれてしまいますが、以下のようなことがわかってきました。
# - ファイル名で確認すると、画像の重複はtrainとtestではない。
# - ボケての文章の長さを確認すると、面白いボケての方が文章が長い傾向
# - 画像とボケての文章を見てみると、確かに１と０で差がありそう（個人的に０の方はどのようにボケているのかが少しわかりにくい感じがあります）
#
# 今回は単純に文章の長さのみを確認しましたが、他にも文章自体について注目していくと、面白さに関する知見というのが見えてくるかも知れません。

# %% [markdown]
# # Create Image Features
#
# ボケてというものは、画像と文章の組み合わせで面白さを表現しているので、以下にして画像のデータと文章のデータをモデルに学習させるかがポイントになってくるかと思います。
#
# 画像のデータを特徴量として用いるために、今回はDenseNet121の学習済みモデルを用います。

# %%
import cv2
from keras.models import Model
from keras.layers import GlobalAveragePooling2D, Input, Lambda, AveragePooling1D
import keras.backend as K
from tqdm import tqdm, tqdm_notebook
from keras.applications.efficientnet_v2 import preprocess_input, EfficientNetV2B2

# %%
class CFG:
    img_size = 260
    batch_size = 17

# %%
def resize_to_square(im):
    old_size = im.shape[:2] 
    ratio = float(CFG.img_size)/max(old_size)
    new_size = tuple([int(x*ratio) for x in old_size])
    # 画像サイズを224×224に変更します
    im = cv2.resize(im, (new_size[1], new_size[0]))
    delta_w = CFG.img_size - new_size[1]
    delta_h = CFG.img_size - new_size[0]
    top, bottom = delta_h//2, delta_h-(delta_h//2)
    left, right = delta_w//2, delta_w-(delta_w//2)
    color = [0, 0, 0]
    new_im = cv2.copyMakeBorder(im, top, bottom, left, right, cv2.BORDER_CONSTANT,value=color)
    return new_im


def load_image(ids, is_train=True):
  if is_train:
    image = cv2.imread(train_image_path+ids)
  else:
    image = cv2.imread(test_image_path+ids)
  new_image = resize_to_square(image)
  new_image = preprocess_input(new_image)
  return new_image

# %%
inp = Input((260,260,3))
backbone = EfficientNetV2B2(input_tensor = inp, include_top = False)
x = backbone.output
x = GlobalAveragePooling2D()(x)
x = Lambda(lambda x: K.expand_dims(x,axis = -1))(x)
x = AveragePooling1D(4)(x)
out = Lambda(lambda x: x[:,:,0])(x)

m = Model(inp,out)
# Out:
# '\ninp = Input((260,260,3))\nbackbone = EfficientNetV2B2(input_tensor = inp, include_top = False)\nx = backbone.output\nx = GlobalAveragePooling2D()(x)\nx = Lambda(lambda x: K.expand_dims(x,axis = -1))(x)\nx = AveragePooling1D(4)(x)\nout = Lambda(lambda x: x[:,:,0])(x)\n\nm = Model(inp,out)\n'

# %%
image_df_train = train_df[["id", "odai_photo_file_name"]].copy()
image_df_train.head()
# Out:
# '\nimage_df_train = train_df[["id", "odai_photo_file_name"]].copy()\nimage_df_train.head()\n'

# %%
image_ids = image_df_train["odai_photo_file_name"].values
n_batches = len(image_ids) // CFG.batch_size + 1

# %%
features = {}
for b in tqdm(range(n_batches)):
    start = b*CFG.batch_size
    end = (b+1)*CFG.batch_size
    batch_ids = image_ids[start:end]
    batch_images = np.zeros((len(batch_ids),CFG.img_size,CFG.img_size,3))
    for i,image_id in enumerate(batch_ids):
        try:
            batch_images[i] = load_image(image_id)
        except:
          print("Error")
    batch_preds = m.predict(batch_images)
    for i,image_id in enumerate(batch_ids):
        features[image_id] = batch_preds[i]
# Out:
# '\nfeatures = {}\nfor b in tqdm(range(n_batches)):\n    start = b*CFG.batch_size\n    end = (b+1)*CFG.batch_size\n    batch_ids = image_ids[start:end]\n    batch_images = np.zeros((len(batch_ids),CFG.img_size,CFG.img_size,3))\n    for i,image_id in enumerate(batch_ids):\n        try:\n            batch_images[i] = load_image(image_id)\n        except:\n          print("Error")\n    batch_preds = m.predict(batch_images)\n    for i,image_id in enumerate(batch_ids):\n        features[image_id] = batch_preds[i]\n'

# %%
image_feature = pd.DataFrame.from_dict(features, orient='index').add_prefix("EfficientNetV2B2_").reset_index()
image_feature.rename(columns={"index":"odai_photo_file_name"}, inplace=True)

# %%
# trainのデータに結合します。
train_df = pd.merge(train_df, image_feature, on="odai_photo_file_name", how="left")

# %%
train_df.shape
# Out:
# (24962, 5)

# %%
# testデータでも同様なことを行って行きます
image_df_test = test_df[["id", "odai_photo_file_name"]].copy()

image_ids = image_df_test["odai_photo_file_name"].values
n_batches = len(image_ids) // CFG.batch_size + 1


features = {}
for b in tqdm(range(n_batches)):
    start = b*CFG.batch_size
    end = (b+1)*CFG.batch_size
    batch_ids = image_ids[start:end]
    batch_images = np.zeros((len(batch_ids),CFG.img_size,CFG.img_size,3))
    for i,image_id in enumerate(batch_ids):
        try:
            batch_images[i] = load_image(image_id, is_train=False)
        except:
          print("Error")
    batch_preds = m.predict(batch_images)
    for i,image_id in enumerate(batch_ids):
        features[image_id] = batch_preds[i]

image_feature = pd.DataFrame.from_dict(features, orient='index').add_prefix("EfficientNetV2B2_").reset_index()
image_feature.rename(columns={"index":"odai_photo_file_name"}, inplace=True)

test_df = pd.merge(test_df, image_feature, on="odai_photo_file_name", how="left")
# Out:
# '\n# testデータでも同様なことを行って行きます\nimage_df_test = test_df[["id", "odai_photo_file_name"]].copy()\n\nimage_ids = image_df_test["odai_photo_file_name"].values\nn_batches = len(image_ids) // CFG.batch_size + 1\n\n\nfeatures = {}\nfor b in tqdm(range(n_batches)):\n    start = b*CFG.batch_size\n    end = (b+1)*CFG.batch_size\n    batch_ids = image_ids[start:end]\n    batch_images = np.zeros((len(batch_ids),CFG.img_size,CFG.img_size,3))\n    for i,image_id in enumerate(batch_ids):\n        try:\n            batch_images[i] = load_image(image_id, is_train=False)\n        except:\n          print("Error")\n    batch_preds = m.predict(batch_images)\n    for i,image_id in enumerate(batch_ids):\n        features[image_id] = batch_preds[i]\n\nimage_feature = pd.DataFrame.from_dict(features, orient=\'index\').add_prefix("EfficientNetV2B2_").reset_index()\nimage_feature.rename(columns={"index":"odai_photo_file_name"}, inplace=True)\n\ntest_df = pd.merge(test_df, image_feature, on="odai_photo_file_name", how="left")\n'

# %%
test_df.shape
# Out:
# (6000, 4)

# %%
train_df.to_csv('embedding_train_image_EfficientNetV2B2')

# %%
test_df.to_csv('embedding_test_image_EfficientNetV2B2')

# %% [markdown]
# # Create Text Features
#
# 続いてボケての文章について、BERTモデルを用いて特徴量化していきます。
# 特徴量化については、以下のディスカッションを参考にさせていただきます。
# [japanese-roberta-baseでテキストデータをembeddingする(小説家になろう ブクマ数予測 \~”伸びる”タイトルとは？\~ より)](https://www.nishika.com/competitions/21/topics/163)

# %%
def clean_text(text):
    replaced_text = text.lower()
    replaced_text = re.sub(r'[【】]', ' ', replaced_text)       # 【】の除去
    replaced_text = re.sub(r'[（）()]', ' ', replaced_text)     # （）の除去
    replaced_text = re.sub(r'[［］\[\]]', ' ', replaced_text)   # ［］の除去
    replaced_text = re.sub(r'[『』]', ' ', replaced_text)   # 『』の除去
    replaced_text = re.sub(r'[@＠]\w+', '', replaced_text)  # メンションの除去
    replaced_text = re.sub(r'https?:\/\/.*?[\r\n ]', '', replaced_text)  # URLの除去
    replaced_text = re.sub(r'　', ' ', replaced_text)  # 全角空白の除去
    replaced_text = re.sub(r' ', '', replaced_text)  # 空白の除去
    return replaced_text


def clean_html_tags(html_text):
    soup = BeautifulSoup(html_text, 'html.parser')
    cleaned_text = soup.get_text()
    cleaned_text = ''.join(cleaned_text.splitlines())
    return cleaned_text


def clean_html_and_js_tags(html_text):
    soup = BeautifulSoup(html_text, 'html.parser')
    [x.extract() for x in soup.findAll(['script', 'style'])]
    cleaned_text = soup.get_text()
    cleaned_text = ''.join(cleaned_text.splitlines())
    return cleaned_text


def clean_url(html_text):
    cleaned_text = re.sub(r'http\S+', '', html_text)
    return cleaned_text


def normalize(text):
    normalized_text = normalize_unicode(text)
    normalized_text = normalize_number(normalized_text)
    normalized_text = lower_text(normalized_text)
    return normalized_text


def lower_text(text):
    return text.lower()


def normalize_unicode(text, form='NFKC'):
    normalized_text = unicodedata.normalize(form, text)
    return normalized_text


def normalize_number(text):
    replaced_text = re.sub(r'\d+', '0', text)
    return replaced_text


def text_cleaning(text):
    text = clean_text(text)
    text = clean_html_tags(text)
    text = clean_html_and_js_tags(text)
    text = clean_url(text)
    text = normalize(text)
    text = lower_text(text)
    text = normalize_unicode(text)

    return text

# %%
from transformers import ElectraModel
from sudachitra import ElectraSudachipyTokenizer

class ElectraSequenceVectorizer:
    def __init__(self, model_name: str):
        self.device = 'cuda' if torch.cuda.is_available() else 'cpu'
        self.model_name = model_name
        self.tokenizer = ElectraSudachipyTokenizer.from_pretrained(self.model_name)
        #self.tokenizer.do_lower_case = True 
        self.electra_model = ElectraModel.from_pretrained(self.model_name)
        self.electra_model = self.electra_model.to(self.device)
        self.max_len = 256


    def vectorize(self, sentence : str) -> np.array:
        inp = self.tokenizer.encode(sentence)
        len_inp = len(inp)

        if len_inp >= self.max_len:
            inputs = inp[:self.max_len]
            masks = [1] * self.max_len
        else:
            inputs = inp + [0] * (self.max_len - len_inp)
            masks = [1] * len_inp + [0] * (self.max_len - len_inp)

        inputs_tensor = torch.tensor([inputs], dtype=torch.long).to(self.device)
        masks_tensor = torch.tensor([masks], dtype=torch.long).to(self.device)

        electra_out = self.electra_model(inputs_tensor, masks_tensor)
        seq_out = electra_out['last_hidden_state']

        if torch.cuda.is_available():    
            return seq_out[0][0].cpu().detach().numpy()
        else:
            return seq_out[0][0].detach().numpy()

# %%
ESV = ElectraSequenceVectorizer('megagonlabs/transformers-ud-japanese-electra-base-ginza-510')

## テキストの欠損値を補間します
train_df["text"] = train_df["text"].fillna('NaN')
test_df["text"] = test_df["text"].fillna('NaN')

## BERT特徴量 
features_text_train = np.stack(train_df["text"].fillna("").map(lambda x: ESV.vectorize(x).reshape(-1)).values)
features_text_test = np.stack(test_df["text"].fillna("").map(lambda x: ESV.vectorize(x).reshape(-1)).values)

# %%
## テキスト特徴量
features_text_train_df = pd.DataFrame(features_text_train).add_prefix("ginza510-electra-large-text")
features_text_test_df = pd.DataFrame(features_text_test).add_prefix("ginza510-electra-large-text")

train_df = pd.concat([train_df, features_text_train_df], axis=1)
test_df = pd.concat([test_df, features_text_test_df], axis=1)

# %%
print(train_df.shape)
print(test_df.shape)
# Out:
# (24962, 773)
# (6000, 772)

# %%
train_df["is_laugh"].value_counts()
# Out:
# 0    12481
# 1    12481
# Name: is_laugh, dtype: int64

# %% [markdown]
# # Data Split

# %%
print(train_df)
# Out:
#               id odai_photo_file_name  \
# 0      ge5kssftl       9fkys1gb2r.jpg
# 1      r7sm6tvkj       c6ag0m1lak.jpg
# 2      yp5aze0bh       whtn6gb9ww.jpg
# 3      ujaixzo56       6yk5cwmrsy.jpg
# 4      7vkeveptl       0i9gsa2jsm.jpg
# ...          ...                  ...
# 24957  xa2nruec1       5ctq9ohpge.jpg
# 24958  dl8r1idfv       dcj9pepjwf.jpg
# 24959  kabzw7bxm       ks04y4iy7i.jpg
# 24960  4blagy0gf       cgfkktchbz.jpg
# 24961  of5eofmq6       jwulli1cmi.jpg
#
#                                                 text  is_laugh  text_len  \
# 0                 君しょっちゅうソレ自慢するけど、ツムジ２個ってそんなに嬉しいのかい？         0        34
# 1                                これでバレない？授業中寝てもバレない？         0        19
# 2      「あなたも感じる？」\n『ああ…、感じてる…』\n「後ろに幽霊いるよね…」\n『女のな…』         0        42
# 3                     大塚愛聞いてたらお腹減った…さく、らんぼと牛タン食べたい…          0        30
# 4                                        熊だと思ったら嫁だった         0        11
# ...                                              ...       ...       ...
# 24957                            え、いいんすか？マジっすか？あざーっす         0        19
# 24958                                 しかし回り込まれてしまった！         1        14
# 24959                 緑でもない中を走り抜けてく♪真っ赤でもないポルシェでもない♪         1        30
# 24960              後ろのサングラスの友達を撮ろうとしたが、思いっきり割り込んできた。         0        33
# 24961                                 待って、今西田敏行になるから         1        14
#
#        ginza510-electra-base-text0  ginza510-electra-base-text1  \
# 0                         0.127659                    -0.048362
# 1                        -0.232022                     0.002564
# 2                        -0.360246                    -0.035453
# 3                        -0.267623                     0.098902
# 4                        -0.442861                     0.001645
# ...                            ...                          ...
# 24957                    -0.302044                    -0.097799
# 24958                    -0.323738                     0.152912
# 24959                    -0.796811                    -0.412796
# 24960                    -0.194888                     0.098630
# 24961                    -0.097510                    -0.071053
#
#        ginza510-electra-base-text2  ginza510-electra-base-text3  \
# 0                         0.592161                     0.622718
# 1                         0.237081                     0.668408
# 2                         0.295524                     0.531373
# 3                         0.170848                     0.710453
# 4                         0.227125                     0.667014
# ...                            ...                          ...
# 24957                     0.342889                     0.638186
# 24958                     0.106184                     0.709541
# 24959                     0.457356                     0.348213
# 24960                     0.316330                     0.709513
# 24961                     0.459837                     0.818590
#
#        ginza510-electra-base-text4  ginza510-electra-base-text5  \
# 0                        -0.122385                     0.773435
# 1                        -0.126845                     1.005075
# 2                        -0.006092                     0.975034
# 3                         0.165454                     1.234050
# 4                        -0.504683                     1.066984
# ...                            ...                          ...
# 24957                    -0.046556                     1.165284
# 24958                    -0.278486                     0.799245
# 24959                    -0.201486                     1.025743
# 24960                    -0.280272                     0.799250
# 24961                     0.050911                     0.800201
#
#        ginza510-electra-base-text6  ginza510-electra-base-text7  \
# 0                         0.152047                    -0.275103
# 1                        -0.061141                    -0.221448
# 2                        -0.021668                    -0.315946
# 3                         0.025378                    -0.676519
# 4                        -0.091260                    -0.490991
# ...                            ...                          ...
# 24957                    -0.024936                    -0.105237
# 24958                    -0.223552                    -0.560866
# 24959                     0.126424                    -0.306357
# 24960                    -0.033044                    -0.619043
# 24961                    -0.225615                    -0.264135
#
#        ginza510-electra-base-text8  ginza510-electra-base-text9  \
# 0                         0.308108                     0.021901
# 1                         0.159402                    -0.098719
# 2                         0.062392                    -0.157364
# 3                         0.246442                     0.026439
# 4                         0.294756                    -0.201638
# ...                            ...                          ...
# 24957                     0.106680                    -0.169741
# 24958                     0.332850                    -0.190087
# 24959                     0.564889                    -0.278080
# 24960                     0.347306                     0.045257
# 24961                     0.032911                     0.247077
#
#        ginza510-electra-base-text10  ginza510-electra-base-text11  \
# 0                         -0.187362                      0.790484
# 1                         -0.325521                      0.444112
# 2                         -0.325179                      0.720861
# 3                         -0.417588                      0.246358
# 4                         -0.362648                      0.708257
# ...                             ...                           ...
# 24957                     -0.437235                      0.775332
# 24958                     -0.580446                      0.654775
# 24959                     -0.359081                      0.558461
# 24960                     -0.464306                      0.925587
# 24961                     -0.095486                      0.868795
#
#        ginza510-electra-base-text12  ginza510-electra-base-text13  \
# 0                         -0.285260                     -0.292867
# 1                         -0.438787                     -0.469968
# 2                         -0.255855                     -0.372035
# 3                         -0.078973                     -0.172163
# 4                         -0.410235                     -0.713556
# ...                             ...                           ...
# 24957                     -0.326293                     -0.554673
# 24958                     -0.559819                     -0.542533
# 24959                     -0.419297                     -0.473287
# 24960                     -0.421697                     -0.372572
# 24961                     -0.334732                     -0.275854
#
#        ginza510-electra-base-text14  ginza510-electra-base-text15  \
# 0                         -0.381315                      0.191788
# 1                         -0.154785                      0.063123
# 2                         -0.229589                     -0.108529
# 3                         -0.060526                      0.033498
# 4                         -0.120529                      0.204394
# ...                             ...                           ...
# 24957                     -0.047387                     -0.086095
# 24958                     -0.155743                      0.108977
# 24959                      0.029824                     -0.104892
# 24960                     -0.334790                      0.382176
# 24961                     -0.164513                      0.214928
#
#        ginza510-electra-base-text16  ginza510-electra-base-text17  \
# 0                          0.787317                     -0.040736
# 1                          0.452320                      0.057190
# 2                          0.604157                      0.028935
# 3                          0.552918                     -0.058957
# 4                          0.296748                     -0.131701
# ...                             ...                           ...
# 24957                      0.566803                      0.014336
# 24958                      0.616393                      0.088393
# 24959                      0.338702                     -0.213235
# 24960                      0.688247                     -0.017285
# 24961                      0.740172                      0.092999
#
#        ginza510-electra-base-text18  ginza510-electra-base-text19  \
# 0                         -0.271748                     -0.320448
# 1                         -0.248604                     -0.129724
# 2                          0.012289                     -0.101809
# 3                         -0.081857                     -0.069136
# 4                         -0.297037                      0.099370
# ...                             ...                           ...
# 24957                     -0.308730                     -0.081456
# 24958                     -0.146048                      0.190700
# 24959                     -0.078147                     -0.077784
# 24960                      0.289879                     -0.090422
# 24961                     -0.046756                     -0.180799
#
#        ginza510-electra-base-text20  ginza510-electra-base-text21  \
# 0                         -0.582465                      0.583010
# 1                         -0.424330                      0.737690
# 2                         -0.555502                      0.332042
# 3                         -0.516929                      0.509460
# 4                         -0.258409                      0.595477
# ...                             ...                           ...
# 24957                     -0.478347                      0.378125
# 24958                     -0.373397                      0.575430
# 24959                     -0.171065                      0.398865
# 24960                     -0.342034                      0.669425
# 24961                     -0.617299                      0.620821
#
#        ginza510-electra-base-text22  ginza510-electra-base-text23  \
# 0                          0.418609                      0.066180
# 1                          0.098687                      0.137234
# 2                          0.302710                      0.214906
# 3                          0.505219                      0.093944
# 4                          0.486876                      0.064813
# ...                             ...                           ...
# 24957                      0.243713                      0.236234
# 24958                      0.442565                      0.008195
# 24959                      0.297770                      0.135968
# 24960                      0.575837                     -0.068419
# 24961                      0.515128                     -0.013633
#
#        ginza510-electra-base-text24  ginza510-electra-base-text25  \
# 0                          0.351957                      0.179235
# 1                          0.281284                      0.535528
# 2                          0.124214                      0.663816
# 3                          0.099289                      0.608807
# 4                          0.656288                      0.513079
# ...                             ...                           ...
# 24957                      0.226879                      0.614311
# 24958                      0.587886                      0.345368
# 24959                      0.350224                      0.511255
# 24960                      0.470100                      0.026149
# 24961                      0.498999                      0.173170
#
#        ginza510-electra-base-text26  ginza510-electra-base-text27  \
# 0                         -0.096813                      0.380738
# 1                         -0.125415                      0.434752
# 2                         -0.316417                      0.616495
# 3                         -0.317731                      0.687836
# 4                          0.080760                     -0.006909
# ...                             ...                           ...
# 24957                     -0.312736                      0.509298
# 24958                      0.166041                      0.287586
# 24959                     -0.039877                      0.516698
# 24960                      0.342389                      0.204482
# 24961                     -0.240217                      0.305217
#
#        ginza510-electra-base-text28  ginza510-electra-base-text29  \
# 0                         -0.473046                      0.083334
# 1                         -0.411134                     -0.038957
# 2                         -0.370366                      0.228793
# 3                         -0.280221                      0.297269
# 4                         -0.283424                      0.262979
# ...                             ...                           ...
# 24957                     -0.864009                      0.454769
# 24958                     -0.431592                      0.296190
# 24959                     -0.510740                      0.340080
# 24960                     -0.379583                      0.109752
# 24961                     -0.409420                      0.054460
#
#        ginza510-electra-base-text30  ginza510-electra-base-text31  \
# 0                          0.187670                      0.170945
# 1                         -0.226952                     -0.229593
# 2                         -0.525860                      0.082162
# 3                         -0.408928                     -0.069370
# 4                         -0.164967                     -0.409429
# ...                             ...                           ...
# 24957                     -0.082040                     -0.016657
# 24958                     -0.207057                     -0.241849
# 24959                     -0.049996                     -0.790959
# 24960                      0.082055                     -0.260092
# 24961                      0.003073                     -0.000463
#
#        ginza510-electra-base-text32  ginza510-electra-base-text33  \
# 0                          0.566813                      0.543496
# 1                          0.515868                      0.844536
# 2                          0.653652                      0.746328
# 3                          0.436017                      0.517509
# 4                          0.583832                      0.871182
# ...                             ...                           ...
# 24957                      0.682079                      0.586167
# 24958                      0.859273                      1.047502
# 24959                      0.276369                      0.778532
# 24960                      0.484318                      0.910607
# 24961                      0.609541                      0.740784
#
#        ginza510-electra-base-text34  ginza510-electra-base-text35  \
# 0                         -0.362723                      0.533108
# 1                         -0.439800                      0.744909
# 2                         -0.199060                      0.678213
# 3                         -0.233350                      0.576115
# 4                         -0.207947                      0.721888
# ...                             ...                           ...
# 24957                     -0.023020                      0.575842
# 24958                     -0.262120                      0.635472
# 24959                     -0.063486                      0.544302
# 24960                     -0.465014                      0.541998
# 24961                     -0.374259                      0.603135
#
#        ginza510-electra-base-text36  ginza510-electra-base-text37  \
# 0                          0.002787                     -0.389034
# 1                         -0.139077                     -0.349264
# 2                          0.095165                     -0.376214
# 3                          0.108357                     -0.378236
# 4                         -0.012378                     -0.283579
# ...                             ...                           ...
# 24957                      0.232751                     -0.418621
# 24958                     -0.160991                     -0.409213
# 24959                      0.052604                     -0.216722
# 24960                     -0.401546                     -0.338924
# 24961                      0.145404                     -0.444192
#
#        ginza510-electra-base-text38  ginza510-electra-base-text39  \
# 0                          0.553448                      0.258018
# 1                          0.390150                     -0.212084
# 2                          0.370519                     -0.057847
# 3                          0.536896                     -0.232433
# 4                          0.140167                     -0.145953
# ...                             ...                           ...
# 24957                      0.575202                     -0.193456
# 24958                      0.265427                      0.010909
# 24959                      0.460449                     -0.344172
# 24960                      0.372327                     -0.046641
# 24961                      0.471529                     -0.114783
#
#        ginza510-electra-base-text40  ginza510-electra-base-text41  \
# 0                         -0.755186                      0.122410
# 1                         -0.855082                      0.059340
# 2                         -0.677160                      0.082912
# 3                         -0.751579                     -0.109672
# 4                         -1.019143                      0.290384
# ...                             ...                           ...
# 24957                     -0.671691                      0.148245
# 24958                     -1.015663                      0.134153
# 24959                     -0.748391                      0.071892
# 24960                     -0.967038                      0.040351
# 24961                     -0.944772                     -0.160753
#
#        ginza510-electra-base-text42  ginza510-electra-base-text43  \
# 0                          0.223816                     -0.338812
# 1                          0.081567                      0.084103
# 2                          0.120794                     -0.088678
# 3                          0.116992                     -0.180078
# 4                          0.130457                     -0.287134
# ...                             ...                           ...
# 24957                      0.142774                     -0.423468
# 24958                      0.129626                     -0.420395
# 24959                      0.177529                     -0.138178
# 24960                      0.160138                     -0.334365
# 24961                      0.184547                     -0.182592
#
#        ginza510-electra-base-text44  ginza510-electra-base-text45  \
# 0                         -0.570070                      0.356422
# 1                         -0.310376                      0.026996
# 2                         -0.445331                      0.339838
# 3                         -0.319855                      0.290473
# 4                         -0.242301                      0.185564
# ...                             ...                           ...
# 24957                     -0.663824                      0.300587
# 24958                     -0.280435                      0.291008
# 24959                     -0.426132                      0.273144
# 24960                     -0.126875                      0.197276
# 24961                     -0.338555                      0.352276
#
#        ginza510-electra-base-text46  ginza510-electra-base-text47  \
# 0                         -0.275762                      0.143726
# 1                         -0.065641                      0.288828
# 2                         -0.103456                      0.005733
# 3                         -0.258263                      0.194404
# 4                         -0.245175                      0.474806
# ...                             ...                           ...
# 24957                     -0.180182                      0.228577
# 24958                     -0.303282                      0.374070
# 24959                     -0.363223                      0.732061
# 24960                     -0.125228                      0.443712
# 24961                     -0.372454                      0.286582
#
#        ginza510-electra-base-text48  ginza510-electra-base-text49  \
# 0                          0.281119                      0.518328
# 1                          0.253428                      0.060652
# 2                          0.407448                      0.456132
# 3                          0.329737                      0.148667
# 4                          0.200251                      0.348085
# ...                             ...                           ...
# 24957                      0.366620                      0.438667
# 24958                      0.290694                      0.324512
# 24959                      0.222181                      0.095648
# 24960                      0.051325                      0.259064
# 24961                      0.072770                      0.220774
#
#        ginza510-electra-base-text50  ginza510-electra-base-text51  \
# 0                          0.249497                     -0.360340
# 1                          0.335003                     -0.506325
# 2                          0.514637                     -0.430951
# 3                          0.583295                     -0.586524
# 4                          0.540373                     -0.403516
# ...                             ...                           ...
# 24957                      1.042706                     -0.348967
# 24958                      0.604089                     -0.525783
# 24959                      0.748585                     -0.435431
# 24960                      0.068917                     -0.730067
# 24961                      0.201633                     -0.580990
#
#        ginza510-electra-base-text52  ginza510-electra-base-text53  \
# 0                          0.615322                     -0.510167
# 1                          0.719124                     -0.338052
# 2                          0.821868                      0.272638
# 3                          0.824521                     -0.069378
# 4                          0.514450                     -0.608399
# ...                             ...                           ...
# 24957                      0.719958                      0.028331
# 24958                      1.018346                     -0.566701
# 24959                      0.688455                     -0.421167
# 24960                      0.775555                     -0.901862
# 24961                      0.861024                     -0.345445
#
#        ginza510-electra-base-text54  ginza510-electra-base-text55  \
# 0                          0.038918                      0.277813
# 1                          0.131774                      0.339504
# 2                          0.373220                      0.568471
# 3                          0.166825                      0.666001
# 4                          0.118029                      0.470574
# ...                             ...                           ...
# 24957                      0.406076                      0.612489
# 24958                     -0.000927                      0.457520
# 24959                      0.291085                      0.191821
# 24960                     -0.137705                      0.075885
# 24961                     -0.257511                      0.436625
#
#        ginza510-electra-base-text56  ginza510-electra-base-text57  \
# 0                         -0.293354                     -0.198228
# 1                         -0.210899                     -0.043164
# 2                         -0.417335                      0.031646
# 3                         -0.429520                     -0.136107
# 4                         -0.474528                      0.071876
# ...                             ...                           ...
# 24957                     -0.205259                     -0.131671
# 24958                     -0.140190                      0.034133
# 24959                     -0.070958                     -0.003246
# 24960                     -0.344219                     -0.148560
# 24961                     -0.310797                     -0.029638
#
#        ginza510-electra-base-text58  ginza510-electra-base-text59  \
# 0                         -0.254566                     -0.089558
# 1                         -0.203876                      0.139029
# 2                         -0.210795                     -0.237720
# 3                         -0.192013                     -0.076877
# 4                         -0.191086                      0.089140
# ...                             ...                           ...
# 24957                     -0.212359                     -0.467388
# 24958                     -0.183905                      0.025865
# 24959                     -0.174809                     -0.052969
# 24960                     -0.227214                      0.358336
# 24961                     -0.193076                     -0.178295
#
#        ginza510-electra-base-text60  ginza510-electra-base-text61  \
# 0                         -0.191233                      1.011785
# 1                         -0.358155                      0.902899
# 2                         -0.473569                      0.837173
# 3                         -0.489577                      0.896523
# 4                         -0.343239                      0.662683
# ...                             ...                           ...
# 24957                     -0.239732                      1.019014
# 24958                     -0.195450                      0.993965
# 24959                     -0.174486                      0.903133
# 24960                     -0.034534                      0.703660
# 24961                     -0.076415                      0.961358
#
#        ginza510-electra-base-text62  ginza510-electra-base-text63  \
# 0                          0.081549                      0.313138
# 1                          0.243677                      0.883195
# 2                          0.403002                      0.661859
# 3                          0.517716                      0.539005
# 4                          0.383895                      0.782885
# ...                             ...                           ...
# 24957                      0.692310                      0.589259
# 24958                      0.356507                      0.834103
# 24959                      0.507898                      0.545455
# 24960                      0.161990                      0.499018
# 24961                      0.368080                      0.420615
#
#        ginza510-electra-base-text64  ginza510-electra-base-text65  \
# 0                          0.532838                      0.215742
# 1                          0.332573                      0.334487
# 2                          0.326242                      0.318999
# 3                          0.338361                      0.192049
# 4                          0.359102                      0.345931
# ...                             ...                           ...
# 24957                      0.483328                      0.293673
# 24958                      0.399349                      0.286426
# 24959                      0.257959                      0.166729
# 24960                      0.433186                      0.170515
# 24961                      0.471196                      0.166220
#
#        ginza510-electra-base-text66  ginza510-electra-base-text67  \
# 0                         -0.075506                      0.715456
# 1                         -0.081296                      0.305020
# 2                         -0.059765                      0.144019
# 3                         -0.051021                      0.399177
# 4                         -0.003043                      0.710976
# ...                             ...                           ...
# 24957                     -0.114695                      0.262349
# 24958                     -0.011364                      0.400078
# 24959                     -0.043617                      0.230969
# 24960                      0.112605                      0.557587
# 24961                     -0.302791                      0.532911
#
#        ginza510-electra-base-text68  ginza510-electra-base-text69  \
# 0                         -0.322726                      0.028296
# 1                         -0.605606                      0.040254
# 2                         -0.570004                     -0.085988
# 3                         -0.503706                     -0.169806
# 4                         -0.650187                     -0.102391
# ...                             ...                           ...
# 24957                     -0.536777                      0.079327
# 24958                     -0.856564                      0.086832
# 24959                     -0.530634                      0.268921
# 24960                     -0.294491                     -0.214313
# 24961                     -0.649169                      0.154842
#
#        ginza510-electra-base-text70  ginza510-electra-base-text71  \
# 0                          0.283706                     -0.105886
# 1                          0.382091                     -0.289529
# 2                          0.263079                     -0.321858
# 3                          0.396286                     -0.303388
# 4                          0.352857                     -0.255337
# ...                             ...                           ...
# 24957                      0.405998                     -0.142957
# 24958                      0.309155                     -0.250824
# 24959                      0.200792                     -0.346384
# 24960                      0.009033                     -0.420912
# 24961                     -0.063629                     -0.250089
#
#        ginza510-electra-base-text72  ginza510-electra-base-text73  \
# 0                         -0.078643                     -0.515650
# 1                         -0.227244                     -0.242164
# 2                          0.114012                     -0.416740
# 3                         -0.096687                     -0.334632
# 4                         -0.397372                     -0.700060
# ...                             ...                           ...
# 24957                     -0.167090                     -0.363722
# 24958                     -0.373579                     -0.514874
# 24959                     -0.768512                     -0.481529
# 24960                     -0.417221                     -0.743261
# 24961                     -0.138595                     -0.506031
#
#        ginza510-electra-base-text74  ginza510-electra-base-text75  \
# 0                         -0.129292                      0.334074
# 1                         -0.163163                      0.071910
# 2                         -0.123944                      0.076522
# 3                         -0.376604                      0.263421
# 4                         -0.157355                      0.158186
# ...                             ...                           ...
# 24957                     -0.290564                      0.026817
# 24958                     -0.071844                      0.147253
# 24959                     -0.340234                     -0.112751
# 24960                     -0.267118                      0.366682
# 24961                     -0.309460                      0.266752
#
#        ginza510-electra-base-text76  ginza510-electra-base-text77  \
# 0                          0.204397                      0.035855
# 1                          0.315514                     -0.085742
# 2                          0.282238                     -0.309742
# 3                         -0.116528                     -0.206462
# 4                          0.586876                      0.168169
# ...                             ...                           ...
# 24957                     -0.024704                     -0.176353
# 24958                      0.418289                      0.047852
# 24959                      0.097575                     -0.263328
# 24960                      0.432209                      0.097002
# 24961                      0.284814                      0.132332
#
#        ginza510-electra-base-text78  ginza510-electra-base-text79  \
# 0                          0.737065                      0.030525
# 1                          0.487052                      0.096892
# 2                          0.407103                      0.151518
# 3                          0.456900                      0.220984
# 4                          0.435194                     -0.047450
# ...                             ...                           ...
# 24957                      0.245029                     -0.001338
# 24958                      0.223272                      0.104314
# 24959                      0.332702                      0.007900
# 24960                      0.482117                      0.221209
# 24961                      0.689709                      0.077103
#
#        ginza510-electra-base-text80  ginza510-electra-base-text81  \
# 0                         -0.365125                     -0.326752
# 1                          0.186423                     -0.213813
# 2                         -0.047463                     -0.234394
# 3                          0.114131                     -0.215004
# 4                          0.274490                     -0.175552
# ...                             ...                           ...
# 24957                     -0.001679                     -0.258065
# 24958                      0.450782                     -0.222005
# 24959                      0.405592                     -0.194273
# 24960                      0.340011                     -0.232340
# 24961                     -0.181482                     -0.214481
#
#        ginza510-electra-base-text82  ginza510-electra-base-text83  \
# 0                         -0.189270                      0.016702
# 1                         -0.296267                      0.214578
# 2                         -0.277649                      0.232113
# 3                         -0.309182                      0.086927
# 4                         -0.216375                      0.261911
# ...                             ...                           ...
# 24957                     -0.207668                      0.443135
# 24958                     -0.416581                      0.339785
# 24959                      0.021941                     -0.030775
# 24960                     -0.333188                     -0.064476
# 24961                     -0.294196                      0.024333
#
#        ginza510-electra-base-text84  ginza510-electra-base-text85  \
# 0                         -0.178340                      0.170749
# 1                         -0.638252                      0.642928
# 2                         -0.319055                      0.704230
# 3                         -0.795757                      0.632179
# 4                         -0.373099                      0.182713
# ...                             ...                           ...
# 24957                     -0.312527                      0.300843
# 24958                     -0.620489                     -0.021637
# 24959                     -0.427973                      0.196867
# 24960                     -0.409072                      0.076689
# 24961                     -0.444409                      0.171747
#
#        ginza510-electra-base-text86  ginza510-electra-base-text87  \
# 0                         -0.457186                     -0.065174
# 1                         -0.750140                      0.078338
# 2                         -0.677567                      0.053637
# 3                         -0.533782                     -0.040135
# 4                         -0.848270                      0.205391
# ...                             ...                           ...
# 24957                     -0.554001                      0.420468
# 24958                     -0.772857                      0.124219
# 24959                     -0.544666                      0.144442
# 24960                     -0.335097                     -0.236657
# 24961                     -0.745147                      0.338155
#
#        ginza510-electra-base-text88  ginza510-electra-base-text89  \
# 0                          0.029981                     -0.416995
# 1                         -0.079802                     -0.230018
# 2                          0.071250                     -0.334751
# 3                         -0.101741                     -0.138894
# 4                         -0.127528                     -0.228531
# ...                             ...                           ...
# 24957                      0.003053                     -0.301331
# 24958                     -0.024490                     -0.302189
# 24959                     -0.322991                     -0.320722
# 24960                     -0.138161                     -0.278947
# 24961                      0.044022                     -0.442679
#
#        ginza510-electra-base-text90  ginza510-electra-base-text91  \
# 0                         -0.167731                      0.197150
# 1                         -0.408863                     -0.084525
# 2                         -0.478279                     -0.052698
# 3                         -0.582979                      0.154081
# 4                         -0.276309                     -0.025390
# ...                             ...                           ...
# 24957                     -0.160309                      0.071552
# 24958                     -0.497047                      0.024151
# 24959                     -0.349069                     -0.108877
# 24960                     -0.614031                      0.119959
# 24961                     -0.672578                     -0.023113
#
#        ginza510-electra-base-text92  ginza510-electra-base-text93  \
# 0                         -0.179615                     -0.379193
# 1                         -0.229483                     -0.332348
# 2                         -0.352826                     -0.281584
# 3                         -0.004892                     -0.268592
# 4                         -0.329861                     -0.267224
# ...                             ...                           ...
# 24957                      0.021182                     -0.326229
# 24958                     -0.324829                     -0.356560
# 24959                     -0.209717                     -0.258965
# 24960                     -0.426807                     -0.325428
# 24961                     -0.138601                     -0.288627
#
#        ginza510-electra-base-text94  ginza510-electra-base-text95  \
# 0                          0.213807                     -0.135220
# 1                          0.564409                     -0.170762
# 2                          0.437632                     -0.017495
# 3                          0.457511                      0.074390
# 4                          0.653174                     -0.176329
# ...                             ...                           ...
# 24957                      0.532657                     -0.170620
# 24958                      0.681206                     -0.352182
# 24959                      0.374175                     -0.246336
# 24960                      0.366014                      0.078877
# 24961                      0.573456                     -0.171830
#
#        ginza510-electra-base-text96  ginza510-electra-base-text97  \
# 0                         -0.285435                     -0.444041
# 1                         -0.878626                     -0.253351
# 2                         -0.653212                     -0.261272
# 3                         -0.600555                     -0.284572
# 4                         -0.855717                     -0.248912
# ...                             ...                           ...
# 24957                     -0.657976                     -0.359823
# 24958                     -0.846558                     -0.316077
# 24959                     -0.968062                     -0.206502
# 24960                     -0.586061                     -0.314825
# 24961                     -0.670039                     -0.311342
#
#        ginza510-electra-base-text98  ginza510-electra-base-text99  \
# 0                          0.010184                     -0.401752
# 1                          0.266055                     -0.362057
# 2                          0.315787                     -0.364150
# 3                          0.305000                     -0.355252
# 4                          0.142548                     -0.345312
# ...                             ...                           ...
# 24957                      0.289047                     -0.372655
# 24958                      0.243410                     -0.393344
# 24959                      0.192397                     -0.347718
# 24960                     -0.085937                     -0.383432
# 24961                      0.107590                     -0.360610
#
#        ginza510-electra-base-text100  ginza510-electra-base-text101  \
# 0                           0.139487                      -0.281265
# 1                          -0.157702                      -0.151853
# 2                          -0.063350                      -0.075261
# 3                           0.012651                      -0.155456
# 4                           0.109213                      -0.347924
# ...                              ...                            ...
# 24957                       0.016010                      -0.339487
# 24958                       0.252668                      -0.241901
# 24959                      -0.086713                      -0.216456
# 24960                       0.177288                      -0.303680
# 24961                      -0.126628                      -0.644348
#
#        ginza510-electra-base-text102  ginza510-electra-base-text103  \
# 0                           0.137491                       0.265288
# 1                          -0.003891                       0.382288
# 2                           0.190262                       0.355847
# 3                           0.288057                       0.285973
# 4                          -0.036771                       0.338916
# ...                              ...                            ...
# 24957                       0.028062                       0.472621
# 24958                       0.068451                       0.071428
# 24959                      -0.032432                       0.093781
# 24960                       0.187071                      -0.097747
# 24961                       0.005589                       0.235245
#
#        ginza510-electra-base-text104  ginza510-electra-base-text105  \
# 0                          -0.431718                       0.040994
# 1                          -0.614173                       0.085305
# 2                          -0.255678                       0.220628
# 3                          -0.267885                      -0.005986
# 4                          -0.327388                       0.084203
# ...                              ...                            ...
# 24957                      -0.625201                       0.234637
# 24958                      -0.462390                      -0.163232
# 24959                      -0.173700                       0.160753
# 24960                      -0.176978                      -0.112521
# 24961                      -0.339106                       0.102871
#
#        ginza510-electra-base-text106  ginza510-electra-base-text107  \
# 0                           0.328153                       0.207451
# 1                           0.170089                      -0.296675
# 2                           0.381849                      -0.183371
# 3                           0.560861                       0.261504
# 4                           0.228262                       0.109867
# ...                              ...                            ...
# 24957                       0.384691                      -0.568813
# 24958                       0.227653                      -0.144826
# 24959                       0.495516                      -0.309847
# 24960                       0.171321                       0.249575
# 24961                       0.186095                      -0.052664
#
#        ginza510-electra-base-text108  ginza510-electra-base-text109  \
# 0                           0.365391                       0.439191
# 1                           0.281667                       0.333099
# 2                           0.228640                       0.849788
# 3                           0.345792                       0.787472
# 4                           0.087065                       0.383125
# ...                              ...                            ...
# 24957                       0.153734                       1.116684
# 24958                       0.257531                       0.480579
# 24959                       0.258554                       0.503220
# 24960                       0.393038                       0.197850
# 24961                       0.404485                       0.349233
#
#        ginza510-electra-base-text110  ginza510-electra-base-text111  \
# 0                           0.487079                      -0.344288
# 1                           0.070790                      -0.336276
# 2                          -0.106060                      -0.028528
# 3                           0.341858                      -0.586362
# 4                           0.052763                      -0.926707
# ...                              ...                            ...
# 24957                       0.389962                      -0.256802
# 24958                      -0.022731                      -0.391980
# 24959                       0.473758                      -0.371361
# 24960                       0.038940                      -0.462963
# 24961                       0.484319                      -0.403588
#
#        ginza510-electra-base-text112  ginza510-electra-base-text113  \
# 0                          -0.270383                      -0.278153
# ...
# 3                          -0.188394                      -0.223445
# 4                          -0.314704                      -0.196239
# ...                              ...                            ...
# 24957                      -0.479276                      -0.236442
# 24958                      -0.169490                      -0.259078
# 24959                      -0.566888                      -0.174465
# 24960                      -0.178242                      -0.257998
# 24961                      -0.243274                      -0.214554
#
#        ginza510-electra-base-text732  ginza510-electra-base-text733  \
# 0                           0.042104                       0.096326
# 1                           0.491326                       0.420736
# 2                          -0.166466                       0.795185
# 3                          -0.026587                       0.425734
# 4                           0.546369                       0.078209
# ...                              ...                            ...
# 24957                      -0.214558                       0.623051
# 24958                       0.581633                       0.263970
# 24959                       0.512019                       0.617711
# 24960                       0.757495                      -0.032100
# 24961                       0.259424                       0.418052
#
#        ginza510-electra-base-text734  ginza510-electra-base-text735  \
# 0                           0.398935                       0.492300
# 1                           0.175063                       0.334266
# 2                           0.205892                       0.129667
# 3                           0.075328                       0.142423
# 4                           0.102810                       0.562381
# ...                              ...                            ...
# 24957                       0.220221                       0.337199
# 24958                       0.281554                       0.242357
# 24959                      -0.029252                       0.410969
# 24960                       0.230545                       0.589774
# 24961                      -0.048288                       0.446338
#
#        ginza510-electra-base-text736  ginza510-electra-base-text737  \
# 0                          -0.243296                       0.106264
# 1                          -0.248188                      -0.212301
# 2                          -0.414165                      -0.432371
# 3                          -0.436468                      -0.339234
# 4                          -0.025543                      -0.198551
# ...                              ...                            ...
# 24957                      -0.477253                      -0.293740
# 24958                      -0.009350                      -0.107363
# 24959                      -0.400803                      -0.271240
# 24960                       0.125987                      -0.035888
# 24961                      -0.373160                       0.115872
#
#        ginza510-electra-base-text738  ginza510-electra-base-text739  \
# 0                          -0.225481                      -0.137952
# 1                           0.307233                      -0.401675
# 2                           0.126893                      -0.495463
# 3                          -0.002759                      -0.291839
# 4                          -0.095371                      -0.287753
# ...                              ...                            ...
# 24957                      -0.034855                      -0.582802
# 24958                       0.069491                      -0.324404
# 24959                      -0.000675                       0.012494
# 24960                       0.031426                      -0.149076
# 24961                       0.048157                      -0.315398
#
#        ginza510-electra-base-text740  ginza510-electra-base-text741  \
# 0                           0.455933                       0.044189
# 1                           0.354150                      -0.159923
# 2                           0.080577                      -0.136055
# 3                           0.349017                      -0.056576
# 4                           0.490543                      -0.133163
# ...                              ...                            ...
# 24957                      -0.180113                      -0.266009
# 24958                       0.096828                      -0.175816
# 24959                       0.549120                      -0.497682
# 24960                       0.661220                      -0.063039
# 24961                       0.398457                       0.026413
#
#        ginza510-electra-base-text742  ginza510-electra-base-text743  \
# 0                           0.273846                      -0.539523
# 1                           0.723902                      -0.221835
# 2                           0.346257                      -0.659095
# 3                           0.291596                      -0.513427
# 4                           0.118617                      -0.081155
# ...                              ...                            ...
# 24957                      -0.144631                      -0.553890
# 24958                       0.221260                       0.000829
# 24959                       0.404487                      -0.348944
# 24960                       0.234483                      -0.013731
# 24961                       0.250657                      -0.209079
#
#        ginza510-electra-base-text744  ginza510-electra-base-text745  \
# 0                          -0.396809                       1.176663
# 1                          -0.107946                       1.299484
# 2                          -0.109872                       1.252518
# 3                          -0.167842                       1.283545
# 4                          -0.407315                       1.210759
# ...                              ...                            ...
# 24957                       0.048138                       1.215228
# 24958                      -0.177207                       1.186445
# 24959                      -0.343194                       1.111582
# 24960                      -0.469772                       1.245067
# 24961                      -0.354828                       1.199014
#
#        ginza510-electra-base-text746  ginza510-electra-base-text747  \
# 0                          -0.470001                       0.381473
# 1                          -0.804633                       0.195816
# 2                          -0.632849                       0.277698
# 3                          -0.524549                       0.449913
# 4                          -0.749885                       0.093875
# ...                              ...                            ...
# 24957                      -0.227000                       0.165198
# 24958                      -0.844845                       0.325795
# 24959                      -0.407740                       0.209319
# 24960                      -0.483954                       0.793006
# 24961                      -0.777643                       0.626735
#
#        ginza510-electra-base-text748  ginza510-electra-base-text749  \
# 0                          -0.050149                      -0.429412
# 1                          -0.189729                      -0.559519
# 2                          -0.152418                      -0.558855
# 3                          -0.145760                      -0.558682
# 4                          -0.412676                      -0.585360
# ...                              ...                            ...
# 24957                      -0.096254                      -0.195212
# 24958                      -0.290955                      -0.561864
# 24959                      -0.301490                      -0.383918
# 24960                      -0.204238                      -0.509050
# 24961                      -0.165114                      -0.432804
#
#        ginza510-electra-base-text750  ginza510-electra-base-text751  \
# 0                          -0.123958                      -0.314406
# 1                          -0.362939                      -0.551336
# 2                          -0.229241                      -0.581026
# 3                          -0.291012                      -0.402541
# 4                          -0.354171                      -0.782040
# ...                              ...                            ...
# 24957                      -0.291059                      -0.704250
# 24958                      -0.499524                      -0.683327
# 24959                      -0.285366                      -0.831772
# 24960                      -0.349836                      -0.251984
# 24961                      -0.317153                      -0.558984
#
#        ginza510-electra-base-text752  ginza510-electra-base-text753  \
# 0                          -0.564049                      -0.337877
# 1                          -0.640247                      -0.541231
# 2                          -0.663058                      -0.691929
# 3                          -0.666197                      -0.766558
# 4                          -0.598604                      -0.482503
# ...                              ...                            ...
# 24957                      -0.715496                      -0.672996
# 24958                      -0.618661                      -0.812766
# 24959                      -0.833003                      -0.790142
# 24960                      -0.566245                      -0.508508
# 24961                      -0.583637                      -0.405125
#
#        ginza510-electra-base-text754  ginza510-electra-base-text755  \
# 0                          -0.636097                       0.116396
# 1                          -0.858630                       0.203175
# 2                          -0.593310                       0.028198
# 3                          -0.725744                       0.128560
# 4                          -0.930878                      -0.100268
# ...                              ...                            ...
# 24957                      -0.442056                       0.372674
# 24958                      -0.626701                      -0.076704
# 24959                      -0.598890                       0.119062
# 24960                      -0.856415                      -0.180928
# 24961                      -0.531772                       0.092125
#
#        ginza510-electra-base-text756  ginza510-electra-base-text757  \
# 0                           0.127601                      -0.532814
# 1                          -0.003243                      -0.773320
# 2                           0.031675                      -0.878754
# 3                           0.067667                      -0.865748
# 4                           0.080062                      -0.801593
# ...                              ...                            ...
# 24957                      -0.073991                      -0.881839
# 24958                      -0.068780                      -0.966755
# 24959                      -0.219794                      -0.917648
# 24960                       0.006533                      -0.863768
# 24961                       0.003779                      -0.785913
#
#        ginza510-electra-base-text758  ginza510-electra-base-text759  \
# 0                          -0.360569                      -0.351413
# 1                          -0.443704                      -0.749215
# 2                          -0.561342                      -0.466851
# 3                          -0.483988                      -0.231206
# 4                          -0.124283                      -0.542795
# ...                              ...                            ...
# 24957                      -0.171749                      -0.273154
# 24958                      -0.180796                      -0.669093
# 24959                      -0.058899                      -0.429970
# 24960                      -0.310032                      -0.576447
# 24961                      -0.262824                      -0.602797
#
#        ginza510-electra-base-text760  ginza510-electra-base-text761  \
# 0                          -0.365410                      -0.437490
# 1                          -0.430861                      -0.503685
# 2                          -0.352912                      -0.355564
# 3                          -0.506210                      -0.575582
# 4                          -0.266226                      -0.627409
# ...                              ...                            ...
# 24957                      -0.566696                      -0.608358
# 24958                      -0.351926                      -0.392039
# 24959                      -0.053215                      -0.486740
# 24960                      -0.195975                      -0.362758
# 24961                      -0.246180                      -0.552588
#
#        ginza510-electra-base-text762  ginza510-electra-base-text763  \
# 0                          -0.062707                      -0.581058
# 1                          -0.032139                      -0.694626
# 2                          -0.295071                      -0.533902
# 3                          -0.211966                      -0.445620
# 4                          -0.028725                      -0.653947
# ...                              ...                            ...
# 24957                       0.076598                      -0.457929
# 24958                      -0.148185                      -0.721510
# 24959                      -0.020052                      -0.582507
# 24960                       0.006899                      -0.704823
# 24961                      -0.210104                      -0.829030
#
#        ginza510-electra-base-text764  ginza510-electra-base-text765  \
# 0                          -0.160957                      -0.652267
# 1                           0.154340                      -0.627166
# 2                           0.184233                      -0.625842
# 3                          -0.024142                      -0.955300
# 4                           0.530941                      -0.671361
# ...                              ...                            ...
# 24957                       0.579573                      -0.774866
# 24958                       0.635323                      -0.339159
# 24959                       0.266779                      -0.720472
# 24960                       0.004631                      -0.660252
# 24961                       0.114290                      -0.601425
#
#        ginza510-electra-base-text766  ginza510-electra-base-text767
# 0                          -0.278737                      -0.019314
# 1                          -0.184984                      -0.072715
# 2                          -0.086308                      -0.388742
# 3                          -0.140494                      -0.268815
# 4                          -0.004824                       0.325298
# ...                              ...                            ...
# 24957                      -0.222804                      -0.197299
# 24958                       0.017922                       0.166088
# 24959                      -0.247037                       0.201789
# 24960                      -0.078801                       0.494729
# 24961                      -0.086066                       0.133852
#
# [24962 rows x 773 columns]

# %%
train_df.to_csv('embedding_train_text_ginza510_electra_large')

# %%
test_df.to_csv('embedding_test_text_ginza510_electra_large')

# %%
# 学習データと評価データに分割します
train_df, valid_df = train_test_split(train_df, test_size=0.2, random_state=42, stratify=train_df["is_laugh"])

train_y = train_df["is_laugh"]
train_x = train_df.drop(["id", "odai_photo_file_name", "text","is_laugh"], axis=1)

valid_y = valid_df["is_laugh"]
valid_x = valid_df.drop(["id", "odai_photo_file_name", "text","is_laugh"], axis=1)

test_x = test_df.drop(["id", "odai_photo_file_name", "text"], axis=1)

# %%
print(train_x.shape)
print(valid_x.shape)
# Out:
# (19969, 769)
# (4993, 769)

# %% [markdown]
# # Model

# %%
lgbm_params = {  
    "n_estimators": 20000,
    "objective": 'binary',
    "learning_rate": 0.05,
    "num_leaves": 32,
    "random_state": 71,
    "n_jobs": -1,
    "importance_type": "gain",
    'colsample_bytree': .8,
    "reg_lambda": 5,
    "max_depth":5,
    }

lgtrain = lgb.Dataset(train_x, train_y)
lgvalid = lgb.Dataset(valid_x, valid_y)

lgb_clf = lgb.train(
    lgbm_params,
    lgtrain,
    num_boost_round=10000,
    valid_sets=[lgtrain, lgvalid],
    valid_names=['train','valid'],
    early_stopping_rounds=50,
    verbose_eval=50
)
# Out:
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 50 rounds.
# [50]	train's binary_logloss: 0.615449	valid's binary_logloss: 0.660622
# [100]	train's binary_logloss: 0.584792	valid's binary_logloss: 0.661337
# Early stopping, best iteration is:
# [68]	train's binary_logloss: 0.602383	valid's binary_logloss: 0.66026

# %%
# 特徴量の重要度を可視化。
lgb.plot_importance(lgb_clf, figsize=(12,8), max_num_features=50, importance_type='gain')
plt.tight_layout()
plt.show()

# %%
# 評価指標はlog lossだが、accuracyも見てみる

val_pred = lgb_clf.predict(valid_x, num_iteration=lgb_clf.best_iteration)
val_pred_max = np.round(lgb_clf.predict(valid_x)).astype(int)  # クラスに分類
accuracy = sum(valid_y == val_pred_max) / len(valid_y)
print(accuracy)
# Out:
# 0.6112557580612858

# %%
_conf_options = {"normalize": None,}
_plot_options = {
        "cmap": "Blues",
        "annot": True
    }

conf = confusion_matrix(y_true=valid_y,
                        y_pred=val_pred_max,
                        **_conf_options)

fig, ax = plt.subplots(figsize=(8, 8))
sns.heatmap(conf, ax=ax, **_plot_options)
ax.set_ylabel("Label")
ax.set_xlabel("Predict")
# Out:
# Text(0.5, 52.0, 'Predict')

# %% [markdown]
# # Predict

# %%
test_pred = lgb_clf.predict(test_x, num_iteration=lgb_clf.best_iteration)

# %%
submission_df["is_laugh"] = test_pred
submission_df.head()
# Out:
#           id  is_laugh
# 0  rfdjcfsqq  0.530673
# 1  tsgqmfpef  0.396616
# 2  owjcthkz2  0.357486
# 3  rvgaocjyy  0.418889
# 4  uxtwu5i69  0.812732

# %%
submission_df.to_csv(('sub.csv'), index=False)

# %% [markdown]
# 実際に提出して、スコアを確認してみましょう。  精度向上に向けて様々なアイディアがあるかと思いますので、ぜひいろいろとトライしていただければと思います！
#
# - 異なる学習済みモデルでの特徴量化
# - 画像の状況とボケての文章との解離具合を測定する
# - 説明文口調とセリフ口調の分類をしてみる。
# - 画像に何が写っているかを検出し、特徴量に加えてみる（人が写っている。動物が写っている）

# %% [markdown]
# https://lab.mo-t.com/blog/kaggle-shopee
# 前処理については今回は気にしない。最終的なLightgbmにぶっこむ特徴量を増やして選別する方針でいく。
# エンベッディングした結果は保存する。
# 最初は画像は画像、テキストはテキストでエンベッディングする。
# 画像のArcFaceちょっとめんどい、実装できそうならやる
# knn(k=50)を使って、画像、テキストの分類自体はする。
#
# 基本はエンベッディングしたものを使う。
# プラスで、特徴量を足してみる。
# 乖離具合ってどうやって測定するのか
# ・長文？なんかキーになる話がある？画像と関係？わからん
# ・ボケのデザインパターン/ジョナサン・ハイト
# ・既知未知判定ってどうやってやるんだ・・・
# ・ポジネガ距離はおもろい。
# あえて正しいこととは逆なことをして、許されるライン的な話。
# →単純にえぐい言葉やえぐさを分類？なんかいいのないかな。
# 説明文とセリフ文→なんかいい楽な分類ないかな、なかったら頑張る。
# 画像に何が写っているか→うーん、手動しかないかも。
